# %%
import pandas as pd
df = pd.read_csv("../data/credit_card_fraud_10k.csv")
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 df = pd.read_csv("../data/credit_card_fraud_10k.csv")
#       3 print(df.shape)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py:59
#      56 # let init-time option registration happen
#      57 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 59 from pandas.core.api import (
#      60     # dtype
#      61     ArrowDtype,
#      62     Int8Dtype,
#      63     Int16Dtype,
#      64     Int32Dtype,
#      65     Int64Dtype,
#      66     UInt8Dtype,
#      67     UInt16Dtype,
#      68     UInt32Dtype,
#      69     UInt64Dtype,
#      70     Float32Dtype,
#      71     Float64Dtype,
#      72     CategoricalDtype,
#      73     PeriodDtype,
#      74     IntervalDtype,
# ...

# %%
df.info()

# %%
df.shape

# %%
df.isnull().sum()

# %%
df.columns

# %% [markdown]
# 0 = normal transaction
# 1 = fraud transaction

# %%
df['is_fraud'].value_counts()

# %%
df['is_fraud'].value_counts(normalize=True)*100

# %%
pip install --force-reinstall numpy==1.26.4 pandas==2.2.2 scikit-learn==1.4.2 matplotlib seaborn imbalanced-learn==0.12.2
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/15.8 MB 9.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.9/15.8 MB 7.3 MB/s eta 0:00:02
#    --------- ------------------------------ 3.7/15.8 MB 6.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.7/15.8 MB 5.5 MB/s eta 0:00:03
# ...
